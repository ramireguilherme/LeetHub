# %%
resultados = {'ids': [['65', '110', '109', '114', '63', '8', '111', '7', '132', '147']],
 'distances': [[0.20248723030090332,
   0.22823059558868408,
   0.24651628732681274,
   0.25787419080734253,
   0.2644657492637634,
   0.27316737174987793,
   0.2862880229949951,
   0.29288679361343384,
   0.29412686824798584,
   0.2987624406814575]],
 'metadatas': [[{'header': '2.5.1 Equipamentos e Treinamentos dos testes'},
   {'header': '2.7 Testes de Validação e Depuração da Memória DDR5'},
   {'header': '2.7 Testes de Validação e Depuração da Memória DDR5'},
   {'header': '2.8 Etapas Usadas em Testes e Circuitos de Memória/DDR'},
   {'header': '2.5 Confiabilidade'},
   {'header': '2.1 DDR5'},
   {'header': '2.7 Testes de Validação e Depuração da Memória DDR5'},
   {'header': '2.1 DDR5'},
   {'header': 'Plano de Qualificação'},
   {'header': 'Teste HTH: Alta Temperatura e Alta Umidade'}]],
 'embeddings': None,
 'documents': [["\\nÉ notório que o escopo do projeto DDR5 comtemplava os testes em câmaras (testes climáticos), mas como mencionado os testes de confiabilidades são diversos e além dos testes climáticos, foram aplicados testes de vibração, choque, queda e resistência/força, abrangendo todos os 6 protótipos de módulos:  \\n-   Protótipo do Módulo de Memória SODIMM DDR5 8GB 4800Mbps;  \\n-   Protótipo do Módulo de Memória SODIMM DDR5 16GB 4800Mbps;  \\n-   Protótipo do Módulo de Memória UDIMM DDR5 8GB 4800Mbps;  \\n-   Protótipo do Módulo de Memória UDIMM DDR5 16GB 4800Mbps;', '-   Protótipo do Módulo de Memória SODIMM DDR5 8GB 4800Mbps;  \\n-   Protótipo do Módulo de Memória SODIMM DDR5 16GB 4800Mbps;  \\n-   Protótipo do Módulo de Memória UDIMM DDR5 8GB 4800Mbps;  \\n-   Protótipo do Módulo de Memória UDIMM DDR5 16GB 4800Mbps;  \\n-   Protótipo do Módulo de Memória RDIMM DDR5 16GB 4800Mbps;  \\n-   Protótipo do Módulo de Memória RDIMM DDR5 32GB 4800Mbps.  \\nOs testes foram fundamentais para comprovar o desempenho esperado do projeto tanto em hardware, quanto em firmware.  ",
   "', 'O desempenho aprimorado que a DDR5 traz, por sua vez, significa que equipamentos de maior desempenho são necessários para analisar e testar dispositivos habilitados para DDR5. Como solução para esse problema , a Tektronix desenvolveu uma solução aprofundada aproveitando o hardware de osciloscópios e sondas de alta largura de banda, um conjunto com uma plataforma de automação de software totalmente nova. ",
   'Continuando de onde a DDR4 parou, a DDR5 fornecerá inicialmente velocidades de transferência de 3.200 MT/s, até 6.400 MT/s, e está prevista para escalar até 8.400 MT/s no futuro. Com essa nova geração da DDR5, surgiu novos desafios, as taxas de dados mais altas resultaram em uma expansão da largura de banda necessária dos equipamentos de testes, novos procedimentos para medir jitter que se afastam da metodologia tradicional, um elemento totalmente novo para DDR na forma de equalização de receptores e até mesmo a introdução de novos tess padronizados usando dispositivos de montagem, que se juntam como grandes desafios na validação de DDR5 \\\\[11\\\\].',
   "['As etapas a seguir podem ser usadas pelos clientes para verificar se seus produtos atendem às especificações DDR5 \\\\[11\\\\]:  \\n-   Uma sonda Tektronix de alta impedância é soldada ao subsistema DDR que está sendo testado – permitindo o acesso aos sinais elétricos de interesse.  \\n-   O software DDR Tx da Tektronix TekExpress analisa os sinais sondados e os compara com as especificações DDR5. ",
   "Ademais, o objetivo é garantir que um produto atenda, de forma consistente, às expectativas do cliente para executar a função ou as funções pretendidas em um determinado período de tempo sob condições especificadas \\\\[8\\\\]. O projeto das memórias DDR5 contemplou o desenvolvimento das metodologias dos testes de confiabilidade, buscou-se testes onde podíamos executar e estressar as memórias em seus limites, com testes destrutivos e de resistência, como por exemplo os testes de vibração, choque, queda, temperatura/umidade, resistência/força, entre outros, observando a validação funcional e de confiabilidade dos módulos.']",
   "\\nFigura 3: Evolução das memórias DDR', 'Figura 3: Evolução das memórias DDR  \\nÉ notório as novas modificações e tecnologias agregadas as DDR5 em comparação com as DDR4, e portanto, a nova versão terá um inevitável aumento de preço, mas todas as melhorias feitas possibilitará um aumento na eficiência na troca de dados e velocidade, agora ver um aumento de seu uso já em 2022 e em 2023. O resultado principal do projeto é a realização do desenvolvimento dos seguintes módulos de memória, consequentemente a elaboração das metodologias dos testes e validação. ",
   "O software\\xa0Tektronix TekExpress DDR Transmitter(Tx) é um aplicativo de teste automatizado projetado para validar e depurar dispositivos DDR5 com base nos parâmetros definidos na especificação\\xa0[JEDEC](https://www.jedec.org/)\\xa0(Joint Electron Device Engineering Council). A opção DDR5SYS da Tektronix (TekExpress DDR Tx) inclui cobertura completa de teste e várias ferramentas de depuração para o seguinte:  \\n-   Componentes DRAM  \\n-   Componentes de buffer/RCD de dados  \\n-   Placas de sistema  \\n-   Sistemas embarcados  \\n-   Servidores e Cliente/Desktop', '-   Componentes DRAM  \\n-   Componentes de buffer/RCD de dados  \\n-   Placas de sistema  \\n-   Sistemas embarcados  \\n-   Servidores e Cliente/Desktop  \\nO TekExpress DDR Tx suporta a medição de mais de 50 parâmetros elétricos e de temporização DDR5 de acordo com a especificação DDR5 JEDEC. ",
   "Abaixo exemplos das gerações de DDR’s, evolução do design ao logo dos anos e suas especificações quanto a largura da banda, voltagens e pinos \\\\[4\\\\].  \\nFigura 2: Memórias e especificações', 'Figura 2: Memórias e especificações  \\nAs especificações da DDR5 indicam o dobro da velocidade base, saltando de 3.200 MT/s para 6.400 MT/s, com uma frequência de 4.800Mhz a 6.400Mhz e voltagem de 1.1V, outras mudanças incluídas na DDR5 é o comprimento do burst, que dobrou de 8bits para 16bits, além dos canais de memória, que agora contarão com dois de 32bits, que na versão anterior usa um único, abaixo imagem da evolução das DDR’s ao logo dos anos \\\\[4\\\\].  ",
   "['A elaboração de novas metodologias para os testes de qualificação do cliente e melhorias, baseou-se nossas pesquisas, é importante salientar que os estudos dos métodos já usado por eles foram levados em consideração e a partir dessa base, foram criados e discutidas novas formas de avaliação de alguns dos testes. O teste foi seguido por métodos de testes e norma JEDEC, como sabido as normas JEDEC são métodos padrões abertos para a indústria para execução de testes, são diretrizes usados em todo o mundo e também os métodos MIL-STD-883 são padrões de testes para microcircuitos, que fornece vários modos de análise para determinar a resistência do produto.']",
   "['O teste é realizado em câmeras climáticas, submetendo os módulos a alta temperatura e alta umidade, consequentemente, demais testes funcionais podem ser realizados e assim observar a resistência dos componentes e confiabilidade de todo o processo. Foi observado nos detalhes do plano de qualificação - SMART, informa a norma JESD218 como base do teste, entretanto, em nossa pesquisa foi observado que a norma é voltada para os testes de SSD, mas em análise para confirmação se há algum critério na norma, onde determina e válida para os módulos de Memória (DDR5), quanto da Internet das Coisas/IoT (Sigfox/NB-IoT), pois é notório que é uma norma de métodos de testes de resistência também.  "]],
 'uris': None,
 'data': None}

# %%
import matplotlib.pyplot as plt

# %%
ground_truth = ['2.7 Testes de Validação e Depuração da Memória DDR5',
                  '2.5.1 Equipamentos e Treinamentos dos testes',
                  '2.5 Confiabilidade'
                 ]

# %%
colors = ['palegreen' if label in ground_truth else 'lightsalmon' for label in headers]

# %%
headers_order = ['Cronograma de Execução', '2.1 DDR5',
       '2.2 Métodos de testes de dispositivos eletrônicos e semicondutores',
       '2.3 Placas de Circuito Impresso',
       '2.3.1 Montagem de Circuito: Através de Furo - TH (Through-Hole)',
       '2.3.2 Montagem de Circuito: Através da Tecnologia em Superfície - SMT (Surface Mount Technology)',
       '2.3.3 Exemplo dos defeitos em placas de circuito impresso',
       '2.4 Garantia da Qualidade na Qualificação do produto',
       '2.4.1 Projeto para Manufaturabilidade (DFM)',
       '2.4.2 Projeto para Testabilidade (DFT)', '2.5 Confiabilidade',
       '2.5.1 Equipamentos e Treinamentos dos testes',
       '2.5.2 Detalhamente das Câmara Climática - Weiss Technik GMBH',
       '2.6 Testabilidade em Câmeras Climáticas',
       '2.7 Testes de Validação e Depuração da Memória DDR5',
       '2.8 Etapas Usadas em Testes e Circuitos de Memória/DDR',
       '2.9 Testes de Vibração', 'Plano de Qualificação',
       'Testes de Desempenho', 'Teste TS:Choque Térmico',
       'Teste MTO : Temperatura máxima de operação', 'Teste de Vibração',
       'Teste de Impacto Mecânico', 'Teste de Torção',
       'Teste HTH: Alta Temperatura e Alta Umidade',
       'Teste TC: Ciclagem de Temperatura',
       'Teste THB: Temperatura e Umidade - Energizado']

# %%
def sort_points(points, order):

    sorted(points, key=lambda x: order.index(x[0]))
    points = [[header, distance] for header, distance in zip(headers, distances)]

    return points

# %%
points = [[header, distance] for header, distance in zip(headers, distances)]
sorted_points = sort_points(headers, headers_order)
points
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 points = [[header, distance] for header, distance in zip(headers, distances)]
# ----> 2 sorted_points = sort_points(headers, headers_order)
#       3 points
#
# Cell In[40], line 3, in sort_points(points, order)
#       1 def sort_points(points, order):
# ----> 3     sorted(points, key=lambda x: order.index(x[0]))
#       4     points = [[header, distance] for header, distance in zip(headers, distances)]
#       6     return points
#
# Cell In[40], line 3, in sort_points.<locals>.<lambda>(x)
#       1 def sort_points(points, order):
# ----> 3     sorted(points, key=lambda x: order.index(x[0]))
#       4     points = [[header, distance] for header, distance in zip(headers, distances)]
#       6     return points
#
# ValueError: '2' is not in list

# %%
headers = [metadata['header'] for metadata in resultados['metadatas'][0]]
distances = resultados['distances'][0]

colors = ['palegreen' if label in ground_truth else 'lightsalmon' for label in headers]
headers = [header[:10] for header in headers]
#headers = [header[:10] for header in headers]
plt.xlabel('Headers')
plt.scatter(headers, distances, c=colors)
plt.xlabel('Seção')
plt.ylabel('Distância')
plt.title('Distribuição de distâncias de chunks por seção (Atividade 2)')
plt.xticks(rotation=90)
plt.show()

# %%
colors
# Out:
# ['palegreen',
#  'palegreen',
#  'palegreen',
#  'lightsalmon',
#  'palegreen',
#  'lightsalmon',
#  'palegreen',
#  'lightsalmon',
#  'lightsalmon',
#  'lightsalmon']

# %%
sorted_headers = sorted(headers, key=lambda x: headers_order.index(x))
sorted_headers
# Out:
# ['2.1 DDR5',
#  '2.1 DDR5',
#  '2.5 Confiabilidade',
#  '2.5.1 Equipamentos e Treinamentos dos testes',
#  '2.7 Testes de Validação e Depuração da Memória DDR5',
#  '2.7 Testes de Validação e Depuração da Memória DDR5',
#  '2.7 Testes de Validação e Depuração da Memória DDR5',
#  '2.8 Etapas Usadas em Testes e Circuitos de Memória/DDR',
#  'Plano de Qualificação',
#  'Teste HTH: Alta Temperatura e Alta Umidade']
